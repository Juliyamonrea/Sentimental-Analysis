# %%
from googleapiclient.discovery import build
import csv

# %%
api_key = ''#Add Youtube V3 API Link
video_ids = ['OOt0fVwumbQ',
'-G1XbS5koW8',
'qYC_sQfwdvQ',
'pdlGn0uhjiU',
'AY0MjEhL_w8',
'KSsAOtvLy5g',
'pTBYN9zat6s',
'662G6ntGF-g',
'ITVZzaBKKk8',
'7Bdf2MbVE5U',
'E9idCkt8jXI',
'x6dwCZp3oJk',
'mtuBeRwYqiI',
'BWuzjSIsZYY',
'e1AwV8Jd87g',
'KQzC2dd133k',
'vrGOmJTR2yU',
'Bi8-Tw-Xmm4',
'FoYVsB0wmqI',
'I5KD5bv8aHA',
'TwiI3fDeZJQ',
'qkZhncxoajg',
'Ije6sSV6lGs',
'BP44eyGXFRg',
'AOYdmAgkjcc',
'WCOxJJU0oXU',
'dnMCTQzRbNU',
'g87Zwz8mDds',
'jQnVGTUp_Mw',
'6Pnt7XUyPqE',
'jyev0y0s6R4',
'UlwhJsxZPi4',
'Oo6wzOs7r-s',
'S899DusUeRc',
'G9K9-mtAKA8',
'2d6au8zbt7I',
'qG5r_xt5iVw',
'iqlRwhiU_Ao',
'qsBh-f8MuYQ',
'Kuj4qxNFoZQ',
'JQ_QGVck9NY',
'uZR54dY5QBE',
'0yadQijbgCc',
'et7nTkWnwtU',
'sax8UwCVEjA',
'uWNkRlTX_Ug',
'Szk81tEPzV8',
'7gKUntbkHH4',
'AqLgILZYFfg',
'5kxOjflpCAU',
]
def video_comments(video_id):
    # empty list for storing comments and replies
    comments = []

    # creating youtube resource object
    youtube = build('youtube', 'v3', developerKey=api_key)

    # retrieve youtube video results
    video_response=youtube.commentThreads().list(
        part='snippet,replies',
        videoId=video_id,
        textFormat="plainText"
    ).execute()

    # get total number of comments
    total_comments = video_response['pageInfo']['totalResults']

    # iterate video response
    while video_response:
        for item in video_response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            # counting number of reply of comment
            replycount = item['snippet']['totalReplyCount']
            if replycount>0:
                for reply in item['replies']['comments']:
                    reply = reply['snippet']['textDisplay']
                    comments.append([reply])
            comments.append([comment])
            
        # check if there are more comments
        if 'nextPageToken' in video_response:
            video_response = youtube.commentThreads().list(
                part='snippet,replies',
                videoId=video_id,
                textFormat="plainText",
                pageToken=video_response['nextPageToken']
            ).execute()
        else:
            break

    return comments, total_comments

# create list to store all results
all_results = []

# iterate through each video ID and call the video_comments function
for video_id in video_ids:
    comments, total_comments = video_comments(video_id)
    all_results.append([video_id, total_comments, comments])

# write results to csv
with open('comments.csv', mode='w', encoding='utf-8', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Video ID', 'Total Comments', 'Comments'])
    for result in all_results:
        writer.writerow(result)

# %% [markdown]
# # Data exctracted from key words
# In this code data all the comments from the video links is exctrected
# This video links were exctrected from code named Ola_Video _links as the output videolink.txt file
